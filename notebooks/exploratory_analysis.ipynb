# %% [markdown]
# # Exploratory Data Analysis
#
# This notebook contains exploratory data analysis for the LLM research project.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
data = pd.read_csv('../data/your_dataset.csv')

# Display basic statistics
print(data.describe())

# Plot distributions
sns.histplot(data['label'])
plt.show()
# Out:
#              id    label
# count  4.000000  4.00000
# mean   2.500000  0.50000
# std    1.290994  0.57735
# min    1.000000  0.00000
# 25%    1.750000  0.00000
# 50%    2.500000  0.50000
# 75%    3.250000  1.00000
# max    4.000000  1.00000
